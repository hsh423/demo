# %%
import pandas as pd
import urllib
url = 'https://github.com/LeDataSciFi/ledatascifi-2022/blob/main/data/Fannie_Mae_Plus_Data.gzip?raw=true'
fannie_mae = pd.read_csv(url,compression='gzip')
fannie_mae
# Out:
#         Loan_Identifier Origination_Channel     Seller_Name  \
# 0          9.733730e+11                   B           OTHER
# 1          9.276200e+11                   B  PNC BANK, N.A.
# 2          7.176670e+11                   B           OTHER
# 3          9.889510e+11                   C    AMTRUST BANK
# 4          1.908850e+11                   R           OTHER
# ...                 ...                 ...             ...
# 135033     9.204900e+11                   R           OTHER
# 135034     9.666890e+11                   R           OTHER
# 135035     6.616280e+11                   R           OTHER
# 135036     5.102850e+11                   R           OTHER
# 135037     4.330130e+11                   R           OTHER
#
#         Original_Interest_Rate  Original_UPB  Original_Loan_Term  \
# 0                        6.875       32000.0               360.0
# 1                        5.875      200000.0               360.0
# ...

# %%
x = fannie_mae.Original_Interest_Rate

fannie_mae["Original_LTV_(OLTV)"] = fannie_mae["OLTV"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OLTV'
#
# The above exception was the direct cause of the following exception:
#
# ...
